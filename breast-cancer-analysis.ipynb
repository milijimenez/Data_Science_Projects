# %% [markdown]
# ![Breast Cancer Data Analysis (1).png](attachment:1788fad2-0786-458c-89cb-5e634f8ba9f3.png)

# %% [markdown]
# # Table of Contents
# * About Dataset
# * Importing Libraries
# * Loading the Breast Cancer Dataset
# * Data Visualization

# %% [markdown]
# # About Dataset
# This datase was obtained from SEER Program of the NCI which provides information on population-based cancer statistics in November 2017.

# %% [markdown]
# # Importing Libraries

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/breast-cancer/Breast_Cancer.csv

# %% [markdown]
# # Loading the Breast Cancer Dataset

# %%
data = pd.read_csv("/kaggle/input/breast-cancer/Breast_Cancer.csv")
data.head()
# Out:
#    Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0   68  White        Married       T1      N1       IIA
# 1   50  White        Married       T2      N2      IIIA
# 2   58  White       Divorced       T3      N3      IIIC
# 3   58  White        Married       T1      N1       IIA
# 4   47  White        Married       T2      N1       IIB
#
#                differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0      Poorly differentiated     3  Regional           4        Positive
# 1  Moderately differentiated     2  Regional          35        Positive
# 2  Moderately differentiated     2  Regional          63        Positive
# 3      Poorly differentiated     3  Regional          18        Positive
# 4      Poorly differentiated     3  Regional          41        Positive
#
#   Progesterone Status  Regional Node Examined  Reginol Node Positive  \
# 0            Positive                      24                      1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     4024 non-null   int64
#  1   Race                    4024 non-null   object
#  2   Marital Status          4024 non-null   object
#  3   T Stage                 4024 non-null   object
#  4   N Stage                 4024 non-null   object
#  5   6th Stage               4024 non-null   object
#  6   differentiate           4024 non-null   object
#  7   Grade                   4024 non-null   object
#  8   A Stage                 4024 non-null   object
#  9   Tumor Size              4024 non-null   int64
#  10  Estrogen Status         4024 non-null   object
#  11  Progesterone Status     4024 non-null   object
#  12  Regional Node Examined  4024 non-null   int64
#  13  Reginol Node Positive   4024 non-null   int64
# ...

# %%
data.describe().T
# Out:
#                          count       mean        std   min   25%   50%   75%  \
# Age                     4024.0  53.972167   8.963134  30.0  47.0  54.0  61.0
# Tumor Size              4024.0  30.473658  21.119696   1.0  16.0  25.0  38.0
# Regional Node Examined  4024.0  14.357107   8.099675   1.0   9.0  14.0  19.0
# Reginol Node Positive   4024.0   4.158052   5.109331   1.0   1.0   2.0   5.0
# Survival Months         4024.0  71.297962  22.921430   1.0  56.0  73.0  90.0
#
#                           max
# Age                      69.0
# Tumor Size              140.0
# Regional Node Examined   61.0
# Reginol Node Positive    46.0
# Survival Months         107.0

# %% [markdown]
# # Data Visualization
# Colors used to visualize the data set:
#
# ![image.png](attachment:9dc18c1d-27c0-4f99-8037-0cde8d0cbe38.png)

# %%
colours = ["#eeaf61","#fb9062","#ee5d6c","#ce4993","#6a0d83"]

# %% [markdown]
# Getting the break down of the Races of the participants in these study

# %%
ax = sns.countplot(x=data['Race'], palette=colours)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '3413'), Text(0, 0, '291'), Text(0, 0, '320')]

# %% [markdown]
# Getting the break down of the Marital Status of the participants in these study using a count plot and a piechart

# %% [markdown]
# Scatter plot between the age and the tumor size

# %%
sns.countplot(x=data['Marital Status'], palette=colours)
x=data['Marital Status']
length = len(data['Marital Status'])
m_count = 0
d_count = 0
single_count = 0
w_count = 0
se_count = 0
for i in range(length):
    if(x[i]=="Married"):
        m_count = m_count + 1
    if(x[i]=="Divorced"):
        d_count = d_count + 1
    if(x[i]=="Widowed"):
        w_count = w_count + 1
    if(x[i]=="Separated"):
        se_count = se_count + 1
    else:
        single_count = single_count + 1
labels = 'Married', 'Divorced','Single','Widowed','Separated'
sizes = [m_count, d_count, single_count, w_count, se_count]
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels,shadow=True, colors = colours)
# Out:
# ([<matplotlib.patches.Wedge at 0x787e8df16b90>,
# ...
#  [Text(0.4754049506105428, 0.9919627679177215, 'Married'),
#   Text(-0.8503485755677722, 0.6977874318371325, 'Divorced'),
#   Text(-0.3868000899144037, -1.029750304900275, 'Single'),
#   Text(1.089512204760894, -0.1515359880591266, 'Widowed'),
#   Text(1.0997986176789976, -0.021047578277949404, 'Separated')])

# %%
plt.figure(figsize=(10, 6), dpi=120)
plt.scatter(data['Age'],data['Tumor Size'], c="#ee5d6c")
plt.title("Breast Cancer")
plt.xlabel("Age")
plt.ylabel("Tumor Size")
# Out:
# Text(0, 0.5, 'Tumor Size')
